# %% [markdown]
# <a href="https://colab.research.google.com/github/elifsudegokay/Urls/blob/master/FearResults.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1aad7284-3f8e-47cf-af4a-84ff036ff96a" name="files[]" multiple disabled />
#      <output id="result-1aad7284-3f8e-47cf-af4a-84ff036ff96a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fearLabel.csv to fearLabel (1).csv

# %%
import pandas as pd

# %%
import io
df_fear = pd.read_csv(io.BytesIO(uploaded['fearLabel.csv']))

# %%
fearValues = df_fear.values.tolist()

# %%
fearValues
# Out:
# [[' Product Font Joint Romance Outerwear Neck Happy Love Photo caption Sleeve'],
#  [' Gun Firearm Shooting Trigger Recreation Gunshot Arm Airsoft gun Photography Air gun'],
#  [' Text Forehead History Photo caption'],
#  [' Friendship Text Cartoon Fiction Illustration Sky Visual arts Black-and-white Adaptation Monochrome'],
#  [' Fiction Cartoon Art Visual arts Adaptation Illustration Fearful Photo caption Fictional character'],
#  [' Dragon Cg artwork Fictional character Illustration Demon Cryptid Mythical creature Extinction Mythology Art'],
#  [' Face Nose Lip Chin Cheek Forehead Mouth Portrait Jaw Photography'],
#  [' Text Font Line Illustration'],
#  [' Text Font Line'],
#  [' Text Sky Font Flower Plant Headgear Love Mask Fictional character Illustration'],
#  [' Face Selfie Eyebrow Head Nose Forehead Smile Lip Photography Glasses'],
#  [' Text Font Blue Line Organism Thinking'],
#  [' Font Text Black Photo caption Logo Photography Brand Black-and-white Graphics Banner'],
# ...

# %%
df_fear
# Out:
#                                                        0
# 0       Product Font Joint Romance Outerwear Neck Hap...
# 1       Gun Firearm Shooting Trigger Recreation Gunsh...
# 2                    Text Forehead History Photo caption
# 3       Friendship Text Cartoon Fiction Illustration ...
# 4       Fiction Cartoon Art Visual arts Adaptation Il...
# 5       Dragon Cg artwork Fictional character Illustr...
# 6       Face Nose Lip Chin Cheek Forehead Mouth Portr...
# 7                            Text Font Line Illustration
# 8                                         Text Font Line
# 9       Text Sky Font Flower Plant Headgear Love Mask...
# 10      Face Selfie Eyebrow Head Nose Forehead Smile ...
# 11                 Text Font Blue Line Organism Thinking
# 12      Font Text Black Photo caption Logo Photograph...
# 13      Illustration T-shirt Art Poster Printmaking M...
# 14      Riding boot Footwear Lady Leg Tights Knee Boo...
# ...

# %%
for i in range(len(fearValues)):
  temp = str(fearValues[i])
  temp = temp[2:-2]
  d.append(str(temp))

# %%
d = []

# %%
type(d[0])
# Out:
# str

# %%
#create format function for every label 
def format(label_name): 
  
    label_name =''.join(label_name)
  
    label_name = str(label_name)
    label_name = label_name.replace(',','')
    label_name = label_name.replace('  ','')

    label_name = label_name.replace("'", "")

    label_name = label_name.split(' ')
   
    return label_name

# %%
d = format(d)

# %%
d
# Out:
# ['',
#  'Product',
#  'Font',
#  'Joint',
#  'Romance',
#  'Outerwear',
#  'Neck',
#  'Happy',
#  'Love',
#  'Photo',
#  'caption',
#  'Sleeve',
#  'Gun',
#  'Firearm',
#  'Shooting',
#  'Trigger',
#  'Recreation',
#  'Gunshot',
#  'Arm',
#  'Airsoft',
#  'gun',
#  'Photography',
#  'Air',
#  'gun',
#  'Text',
#  'Forehead',
#  'History',
#  'Photo',
#  'caption',
#  'Friendship',
#  'Text',
#  'Cartoon',
#  'Fiction',
#  'Illustration',
#  'Sky',
#  'Visual',
#  'arts',
#  'Black-and-white',
#  'Adaptation',
#  'Monochrome',
#  'Fiction',
#  'Cartoon',
#  'Art',
#  'Visual',
#  'arts',
#  'Adaptation',
#  'Illustration',
#  'Fearful',
#  'Photo',
#  'caption',
#  'Fictional',
#  'character',
#  'Dragon',
#  'Cg',
#  'artwork',
#  'Fictional',
#  'character',
#  'Illustration',
#  'Demon',
#  'Cryptid',
#  'Mythical',
#  'creature',
#  'Extinction',
#  'Mythology',
#  'Art',
#  'Face',
#  'Nose',
#  'Lip',
#  'Chin',
#  'Cheek',
#  'Forehead',
#  'Mouth',
#  'Portrait',
#  'Jaw',
# ...

# %%
len(d)
# Out:
# 131293

# %%
df_fearLabels = pd.DataFrame(d)

# %%
df_fearLabels = pd.DataFrame({'label': d})

# %%
from google.colab import files

df_fearLabels.to_csv('df_fearLabels.csv')
files.download('df_fearLabels.csv')

# %%
df_fearLabels['label'].value_counts()[:50]
# Out:
# Font               5427
# Text               5227
# Sky                2460
# Photography        2293
# Line               2139
# Illustration       2006
# Art                1850
# Photo              1509
# caption            1407
# Black-and-white    1295
# Fictional          1233
# character          1232
# Black              1209
# Face               1142
# design              996
# Smile               981
# photography         947
# Monochrome          946
# Human               935
# Head                930
# Darkness            907
# Adaptation          898
# Tree                891
# Hair                871
# hair                842
# Organism            824
# Nose                820
# Logo                818
# Graphic             779
# Graphics            774
#                    ...
# Dung                  1
# mo                    1
# receiver              1
# Falconiformes         1
# Juggling              1
# Raw                   1
# Lymantria             1
# ...

# %%
df_fearLabels['label'].value_counts()
# Out:
# Font               5427
# Text               5227
# Sky                2460
# Photography        2293
# Line               2139
# Illustration       2006
# Art                1850
# Photo              1509
# caption            1407
# Black-and-white    1295
# Fictional          1233
# character          1232
# Black              1209
# Face               1142
# design              996
# Smile               981
# photography         947
# Monochrome          946
# Human               935
# Head                930
# Darkness            907
# Adaptation          898
# Tree                891
# Hair                871
# hair                842
# Organism            824
# Nose                820
# Logo                818
# Graphic             779
# Graphics            774
#                    ...
# Ibizan                1
# aquarium              1
# Infant                1
# Gunfighter            1
# Hotel                 1
# wraith                1
# Guk                   1
# ...

# %%
df_fearLabels['label'].value_counts()[:50].plot(kind='pie', figsize=(30,20), title='Top 50 Fear Label')

# %%
df_fearLabels['label'].value_counts()[:20].plot(kind='pie', figsize=(30,12), title='Top 20 Fear Label')
