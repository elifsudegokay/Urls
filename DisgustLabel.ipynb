# %% [markdown]
# <a href="https://colab.research.google.com/github/elifsudegokay/Urls/blob/master/DisgustLabel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-241e827d-8d02-437b-be97-601420f0829b" name="files[]" multiple disabled />
#      <output id="result-241e827d-8d02-437b-be97-601420f0829b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving disgustImages.csv to disgustImages (2).csv

# %%
import pandas as pd

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['disgustImages.csv']))

# %%
disgustImageUrls = df2.values.tolist()

# %%
disgustImageUrls
# Out:
# [['https://scontent-sea1-1.cdninstagram.com/vp/1acfbec82faaeb44b36e7d6f1fb925dd/5D021782/t51.2885-15/e35/52151587_429580621122915_157240427433404438_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'],
#  ['https://scontent-sea1-1.cdninstagram.com/vp/479ddd9d7f8d4700d63a95d199945628/5D16AFC9/t51.2885-15/e35/50496254_791661954553629_7029000283686781061_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'],
#  ['https://scontent-sea1-1.cdninstagram.com/vp/599823e984267368e30bb4ca830eaf83/5D0EB905/t51.2885-15/e35/52421024_431174410970491_4902164878483590481_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'],
#  ['https://scontent-sea1-1.cdninstagram.com/vp/bd1fa8e886aa82620e17cda29c08c28c/5D22F9BE/t51.2885-15/e35/41502233_165265911061842_3292957716041993168_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'],
# ...

# %%
# !pip install google-cloud-vision

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/drive/My Drive/Elif Sude Gokay-741ff641f1c1.json"

# %%
from googleapiclient.discovery import build

# %%
KEY = '741ff641f1c16242e0448d696590f7a34c78eed6'
service = build('vision', 'v1', developerKey=KEY)

# %%
# !export GOOGLE_APPLICATION_CREDENTIALS="/content/drive/My Drive/Elif Sude Gokay-741ff641f1c1.json"

# %%
def detect_labels_as_string(uri):
    """Detects labels in the file located in Google Cloud Storage or on the
    Web."""
    from google.cloud import vision
    client = vision.ImageAnnotatorClient()
    image = vision.types.Image()
    image.source.image_uri = uri

    response = client.label_detection(image=image)
    labels = response.label_annotations
    result = ''

    for label in labels:
        result = result + ' ' + label.description
        
    return result

# %%
res = detect_labels_as_string("https://scontent-mia3-1.cdninstagram.com/vp/6adaec81111e082c92f07f205b67aea6/5D212F9A/t51.2885-15/e35/52533075_833143047035613_3843676377940022658_n.jpg?_nc_ht=scontent-mia3-1.cdninstagram.com")

print(res)
# Out:
#  Sky Text Morning Natural landscape Font Happy Photo caption Tree Love Adaptation

# %%
d = []

# %%
for i in range(len(disgustImageUrls)):
  temp = str(disgustImageUrls[i])
  temp = temp[2:-2]
  d.append(str(temp))

# %%
d[3]
# Out:
# 'https://scontent-sea1-1.cdninstagram.com/vp/bd1fa8e886aa82620e17cda29c08c28c/5D22F9BE/t51.2885-15/e35/41502233_165265911061842_3292957716041993168_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'

# %%
print(len(d))
# Out:
# 22082

# %%
res = detect_labels_as_string("https://scontent-sea1-1.cdninstagram.com/vp/0d96e2f0138a01527c71b1074b398cf9/5D08B63E/t51.2885-15/e35/51939627_358425064760661_6064370397371675438_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com")

print(res)
# Out:
#  Furniture Product Table Room Bed Illustration

# %%
res = detect_labels_as_string(d[len(d) -1])

print(res)
# Out:
#  Hair Blond Beauty Surfer hair Long hair Vacation Summer Swimwear Fun Sea

# %%
disgustLabel = []

# %%
for url in range(15000,20000):
    disgustLabel.append(detect_labels_as_string(d[url]))

# %%
disgustLabel[0]
# Out:
# ' Text Footwear Font Illustration Shoe Line art Graphics'

# %%
len(disgustLabel)
# Out:
# 13660

# %%
disgustLabel
# Out:
# [' Font Games',
#  ' Green Lady Turquoise Dress Summer Door Photography Plant Vacation House',
#  ' Cartoon Illustration Nose Cheek Fictional character Forehead Mouth Drawing Sketch Jaw',
#  ' Face Facial expression Forehead Head Text Nose Chin Human Photo caption Selfie',
#  ' Green Fictional character Supervillain Illustration Mouth Art Smile Style',
#  ' Blue Eyewear Hair Glasses Cobalt blue Cool Electric blue Eye Vision care Sunglasses',
#  ' Green Drawing Notebook Sketch Cartoon Illustration Fashion design Fashion illustration Design Pattern',
#  ' Green Leaf vegetable Vegetable Cabbage Food Vegetarian food Illustration Fictional character Cruciferous vegetables Lettuce',
#  ' People Social group Youth Community Team Fun Event Child Leisure Tourism',
#  ' Animated cartoon Toy Cartoon Stuffed toy Animation Action figure Plush Doll Fun Textile',
#  ' Figurine Action figure Toy Games Fictional character Fiction',
# ...

# %%
d[2]
# Out:
# 'https://scontent-sea1-1.cdninstagram.com/vp/e6154b00f42be1148f7022587dd7bd27/5D1A9ED3/t51.2885-15/e35/52736719_414187069124458_8846469124844752753_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'

# %%
len(disgustLabel)
# Out:
# 13930

# %%
dfh = pd. DataFrame(disgustLabel)

# %%
dfh.to_csv("disgustLabel.csv", index = False)

# %%
files.download("disgustLabel.csv")
