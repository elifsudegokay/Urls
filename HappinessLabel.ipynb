# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c2287b1-1268-441d-91ef-598f319c6cd8" name="files[]" multiple disabled />
#      <output id="result-3c2287b1-1268-441d-91ef-598f319c6cd8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving happinessImages.csv to happinessImages.csv

# %%
import pandas as pd

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['happinessImages.csv']))

# %%
happinessImageUrls = df2.values.tolist()

# %%
happinessImageUrls
# Out:
# [['https://scontent-sea1-1.cdninstagram.com/vp/028d86c7ba760ba31cfd2a97f30beef6/5D1DC544/t51.2885-15/e35/52327250_332003064100726_5987930487895639427_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'],
#  ['https://scontent-sea1-1.cdninstagram.com/vp/6a73203682ef6864d5ad7a5dc8e16746/5D0B8191/t51.2885-15/e35/52912680_262087254697750_7133133746057898957_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'],
#  ['https://scontent-sea1-1.cdninstagram.com/vp/d4715ca3e5e7e7d87d2fbd56332ee804/5D0B188A/t51.2885-15/e35/52678120_693250104404113_5354517137237658443_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'],
#  ['https://scontent-sea1-1.cdninstagram.com/vp/76c760c101348f730bc38141254414c8/5D20B497/t51.2885-15/e35/51998100_394666521324070_2263649651173039075_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'],
# ...

# %%
# !pip install google-cloud-vision
# Out:
# ...
#     100% |████████████████████████████████| 389kB 26.4MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/drive/My Drive/Elif Sude Gokay-741ff641f1c1.json"

# %%
from googleapiclient.discovery import build

# %%
KEY = '741ff641f1c16242e0448d696590f7a34c78eed6'
service = build('vision', 'v1', developerKey=KEY)

# %%
# !export GOOGLE_APPLICATION_CREDENTIALS="/content/drive/My Drive/Elif Sude Gokay-741ff641f1c1.json"

# %%
def detect_labels_as_string(uri):
    """Detects labels in the file located in Google Cloud Storage or on the
    Web."""
    from google.cloud import vision
    client = vision.ImageAnnotatorClient()
    image = vision.types.Image()
    image.source.image_uri = uri

    response = client.label_detection(image=image)
    labels = response.label_annotations
    result = ''

    for label in labels:
        result = result + ' ' + label.description
        
    return result

# %%
res = detect_labels_as_string("https://scontent-sea1-1.cdninstagram.com/vp/a95ac49eeeab4d9f966e30681253901c/5D12F3AF/t51.2885-15/e35/52397803_2288420501181599_2971954263532943903_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com")

print(res)
# Out:
#  People Social group Event Team Fun Cool Smile Ceremony Photography Formal wear

# %%
d = []

# %%
for i in range(len(happinessImageUrls)):
  temp = str(happinessImageUrls[i])
  temp = temp[2:-2]
  d.append(str(temp))

# %%
d[3]
# Out:
# 'https://scontent-sea1-1.cdninstagram.com/vp/76c760c101348f730bc38141254414c8/5D20B497/t51.2885-15/e35/51998100_394666521324070_2263649651173039075_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com'

# %%
res = detect_labels_as_string("https://scontent-sea1-1.cdninstagram.com/vp/76c760c101348f730bc38141254414c8/5D20B497/t51.2885-15/e35/51998100_394666521324070_2263649651173039075_n.jpg?_nc_ht=scontent-sea1-1.cdninstagram.com")

print(res)
# Out:
#  Cartoon Interaction Conversation Gesture Black-and-white

# %%
res = detect_labels_as_string(d[3])

print(res)
# Out:
#  Cartoon Interaction Conversation Gesture Black-and-white

# %%
happinessLabel = []

# %%
for url in range(22000,23000):
    happinessLabel.append(detect_labels_as_string(d[url]))

# %%
happinessLabel
# Out:
# [' Dog Mammal Vertebrate Canidae Dog breed Australian shepherd Puppy Miniature australian shepherd Carnivore Companion dog',
#  ' Food Coffee Brunch Cuisine Meal Drink Dish Child Breakfast Latte macchiato',
#  ' Room Bathtub Furniture Jacuzzi Interior design Bathroom House Kitchen Floor Tile',
#  ' Cartoon Interaction Conversation Gesture Black-and-white',
#  ' Brunch Red Table Interior design Meal Food Furniture Room Breakfast Cuisine',
#  ' People on beach Vacation Fun Summer Beach Sand Leg Sea Recreation Swimwear',
#  ' Photograph Red Wall Brick Pink Photography Brickwork Art Architecture Mural',
#  ' Eyewear Hair Ear Sunglasses Nose Beauty Glasses Organ Lip Hairstyle',
#  ' Text Font Magazine Design Graphic design Material property Advertising Flyer Brochure Illustration',
#  ' Font Text Calligraphy Handwriting Art']

# %%
len(happinessLabel)
# Out:
# 13000

# %%
dfh = pd. DataFrame(happinessLabel)

# %%
dfh.to_csv("happinessLabel2.csv", index = False)

# %%
files.download("happinessLabel2.csv")
